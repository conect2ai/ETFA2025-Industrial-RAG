# %%
# %pip install "unstructured[md]" nltk langchain-text-splitters

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## **Single Document**

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_text_splitters import MarkdownHeaderTextSplitter
from langchain.document_loaders import TextLoader

# Load
markdown_path = "./Processed_Files_Introduction_to_End/CANopen_Integration_7012_V10_Mar11.md"
loader = TextLoader(markdown_path, autodetect_encoding=True)
doc = loader.load()
doc[0]
# Out:
# Document(metadata={'source': './Processed_Files_Introduction_to_End/CANopen_Integration_7012_V10_Mar11.md'}, page_content='# <span id="page-6-0"></span>**5 Introduction**\n\n# <span id="page-6-1"></span>**5.1 Overview**\n\nThis guideline describes the concepts for the integration of fieldbus systems into PROFINET IO. The following aspects are considered:\n\n- Cyclic process data\n- Acyclic parameters\n- Diagnostics\n- Alarms\n- Temporal behavior / Synchronization\n- Startup behavior\n- Engineering\n\nA PROFINET IO Linking Device consists of at least two communication channels, one PROFINET IO Device and at least one CANopen Device that shall support SDO Client Functionality and may additionally support NMT Master functionality and a PDO producer / consumer. The application within the Linking Device is the mapper between the PROFINET IO services [2] and the services of [5]. This specification describes the mapping of a PROFINET IO-Device to a set of CANopen Devices.\n\n[Figure 1](#page-6-3) shows an example outline with one specific Linking Device type.\n\n![](_page_6_Figure_13.jpeg)\n\n**Figure 1: Overview of an example CANopen integration** \n\n# <span id="page-6-3"></span><span id="page-6-2"></span>**5.2 Use Cases**\n\nThere are two use cases of integration of CANopen Devices in PROFINET IO:\n\n#### **SUB Use of CANopen Devices as substitute for PROFINET IO devices**\n\n For some applications PROFINET IO devices are not available but CANopen Devices exist that can be a substitute for this application. In this use case it is very important to have a common application model for PROFINET and similar device behavior. The coding of data types is different and should be adjusted.\n\n#### **INF Use of PROFINET as common infrastructure for different applications**\n\nPROFINET allows different Ethernet applications to share the same network. Thus, PROFINET IO and CANopen Devices according to [9] can be operated on the same network. But for realtime applications it would be much better to have a common platform to expedite the conveyance of PDO. In case of isochronous applications (e.g. for motion control) a common communication model is mandatory. But in case of several controllers sharing a common network infrastructure the individual connection may be between two components supporting the CANopen communication model. In this case no data type conversion or adjustment of the application model is needed.\n\nThe main focus of this specification is the SUB use case but the model should not impede the INF use case.\n\n# <span id="page-7-0"></span>**5.3 Workflow of CANopen integration**\n\nCorresponding to the use cases of section [5.2](#page-6-2) the GSD used by PROFINET Engineering will be build typically in two ways. [Figure 2](#page-7-2) shows the INF- and SUB-scenarios:\n\n- **INF** The CANopen Network will be configured by CANopen Network Engineering. That process creates the configuration data for the CANopen Devices as well as a GSD representing the whole CANopen network in its actual configuration. The PROFINET engineering process will generate the missing configuration data for the Linking Device.\n- **SUB** A GSD composer generates from the GSD of the Linking Device and from the EDS of the CANopen Devices a GSD. That GSD can be used by the PROFINET Engineering to generate configuration data for the Linking Device as well as for the CANopen Devices.\n\n![](_page_7_Figure_7.jpeg)\n\n**Figure 2: General Configuration outline** \n\n# <span id="page-7-2"></span><span id="page-7-1"></span>*5.3.1 SUB Use of CANopen Devices as substitute for PROFINET IO devices*\n\nThe detailed workflow of CAN integration is specified in [4]\n\nThe mapping shall ensure that a user of the CANopen Device can see the same behavior as if the device is a PROFINET device. The mapping rules as described here apply.\n\nSome CANopen services may be implemented by a sequence of PROFINET IO services. Thus, the application program at the controller should have t ...

# %%
headers_to_split_on = [
    ("#", "Header 1"),
    ("###", "Header 3"),
    ("####", "Header 4"),
]

# MD splits
markdown_splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on, strip_headers=False
)
md_header_splits = markdown_splitter.split_text(doc[0].page_content)
md_header_splits

# %%
# Char-level splits
chunk_size = 1000
chunk_overlap = 200
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size, chunk_overlap=chunk_overlap
)

# Split
splits = text_splitter.split_documents(md_header_splits)
splits

# %% [markdown]
# ## **All Documents**

# %%
import glob
import os

from langchain_core.documents import Document

# %%
# 1. Path/pattern for markdown files
folder_path = "./Processed_Files_Introduction_to_End/*.md"

# 2. Parameters for the Header Splitter
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
    ("####", "Header 4"),
]
markdown_splitter = MarkdownHeaderTextSplitter(
    headers_to_split_on=headers_to_split_on, 
    strip_headers=False
)

# 3. Parameters for the character-level splitter
chunk_size = 1000
chunk_overlap = 200
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size, 
    chunk_overlap=chunk_overlap
)

# Final list for all splits from all files
all_splits = []

for file_path in glob.glob(folder_path):
    # a) Load the file as raw text (preserving Markdown)
    loader = TextLoader(file_path, autodetect_encoding=True)
    docs = loader.load()  # usually returns a list [Document]
    
    # b) For each Document, perform two splits
    for doc in docs:
        md_header_splits = markdown_splitter.split_text(doc.page_content)
        splits = text_splitter.split_documents(md_header_splits)
        
        # c) Use the base file name as "name_file" (without the path and without extension)
        filename = os.path.splitext(os.path.basename(file_path))[0]

        for splitted_doc in splits:
            splitted_doc.metadata["name_file"] = filename
            # Optionally, remove the original "source" if not needed:
            # splitted_doc.metadata.pop("source", None)

        all_splits.extend(splits)

# %%
min_size = 1000  # Minimum size for the merged chunks
merged_documents = []  # List to store merged documents
buffer_content = ""
buffer_metadata = {}

for doc in all_splits:
    text = doc.page_content.strip()  # remove extra spaces if necessary
    # If there is no content accumulated in the buffer and the chunk is small,
    # initialize the buffer with this chunk.
    if not buffer_content and len(text) < min_size:
        buffer_content = text
        buffer_metadata = doc.metadata
    # If there is already content in the buffer, concatenate it with the current chunk.
    elif buffer_content:
        buffer_content += "\n" + text  # add a line break to separate the texts
        # When the buffer reaches or exceeds the minimum size, create a Document
        if len(buffer_content) >= min_size:
            merged_documents.append(
                Document(page_content=buffer_content, metadata=buffer_metadata)
            )
            buffer_content = ""
            buffer_metadata = {}
    # If the current chunk is already large enough and there is nothing in the buffer, add it directly.
    elif len(text) >= min_size:
        merged_documents.append(Document(page_content=text, metadata=doc.metadata))

# If there is remaining content in the buffer, add it as well.
if buffer_content:
    merged_documents.append(Document(page_content=buffer_content, metadata=buffer_metadata))

# Example of printing the results:
for i, document in enumerate(merged_documents):
    print(f"Document {i+1}:")
    print("Metadata:", document.metadata)
    print("Content (first 200 characters):", document.page_content[:200])
    print("-" * 50)

# %%
print(f"Generated {len(all_splits)} chunks in total.")

# %%
print(f"Generated {len(merged_documents)} chunks in total.")

# %%
merged_documents
# Out:
# [Document(metadata={'Header 1': '**Introduction**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# **Introduction**  \nThis is a Specification that describe Time Stamp Mechanism for PROFIBUS. It fulfils the requirements described in a document from a ZVEI-Team[1].  \nThere are additional mechanisms described related to Time Stamp:  \n- Clock Synchronisation\n- Alert (Alarm and Event)  \nParts of this document must be moved and transformed to other Specification of PNO:  \n- PROFIBUS Data Link Layer [2]\n- PROFIBUS Application Layer [3]\n- PROFIBUS-PA Profile for Process Devices V3.0 October 1999 [4]\n- GSD Description, GSD Revision 3\n# **How to read this document:**  \n**Names of Data Types** are formatted in this document as follows:  \nFirst letter as capital, if the data type name is composed of two or more words then the words are separated by a underline and each word starts with a capital letter. Example:  \nSynch\\_Time  \n**Parameter** names are written in capital letter.  \n**Services** are named as in the appropriate documents.\n# <span id="page-4-0"></span>**1 Scope**  \nTime Stamp describe the behaviour of a plant:  \n- to order messages\n- to identify the sequence of program invocation\n- to make relations between a time stamped message and a program start.\n- to visualise discrete and analogue values, which are transmitted asynchronously.  \nThe deviation of clock between two different communication devices on a common line shell not exceed 1ms.  \nAre there repeater, Coupler or Links between the devices which perform time stamping based on a clock synchronisation shell synchronise the clock better then 10 ms. That means, one event connected to two input modules, which are not on a common line, have to perform a time stamping that do not differ more then 10ms.'),
#  Document(metadata={'Header 1': '<span id="page-4-0"></span>**1 Scope**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='The accuracy of time stamp depends on several aspects. The real deviation is to evaluate within a real application. The scope of this specification is only the aspect of communication. It do not take care about filter, discrete sample time, etc. within a input module. Clock inaccuracies due to other parts of the system must be added.  \nTime Stamping is used to add the clock information to  \n- a alarm when it was detected\n- a event when it occurs.  \nTime Stamp mechanisms are add on functions to the cyclic communication behaviour.  \nThis specification specifies the Clock Synchronisation mechanism to synchronise the time between devices on a PROFIBUS segment. The accuracy which can been achieved by the Clock Synchronisation mechanism described in this specification applies to clocks which are immediately controlled by the DDLM entities.\n# <span id="page-5-0"></span>**2 Definition**  \n**Slot**: see DP V1 Spec.  \n**I/O\\_Channel**: represents the Input or Output signal within a module, which is mapped to a Slot.  \n**Signal**: is the process value (sensor value or output value to an actor) at the interface to the module  \n**Index**: sub address of a PROFIBUS DP-V1 slot.  \n**Sampling**: This is the mechanism to build a buffer of events.  \n**event**: This is a signal / I/O\\_Channel / PV at the time where a trigger condition arise. It will be stored in a buffer.  \nA \'**time master\'** is a Profibus master which is able to send time synchronisation telegrams. Any class 1 or class 2 master may be a time master.  \nA \'**time receiver\'** can be time synchronised by the Profibus. Any active Profibus device can be a time receiver (master class 1, master class 2, slave).  \nA \'**DP/PA link device\'** normally is a time receiver on one side and a time master on the other side.'),
#  Document(metadata={'Header 1': '**3 System Architecture**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# **3 System Architecture**  \nIn behalf of a description of System Architecture in this clause see separate file "Anforderung TimeStamp\\_V05\\_00313 (German language only)"\n# **4 Data Type Definitions**\n# **4.1 Additional Time Formats**  \nTime Synchronisation and Time Stamped Parameters need an additional format. The used format is based on the RFC 1305 standard. This format normally counts up the seconds from 1.1.1900. Without additional definitions there is a wrap around in 7.2. 2036 6.28,16.  \nThe following definition is made to avoid the wrap around mentioned above. All counted values, which represent a time before 1.1.1984 are mapped after the 7.2. 2036 6.28,16.  \n![](_page_5_Figure_18.jpeg)\n#### **Figure 4-1 Time Format definition**\n# **4.1.1 Synch\\_Time Data Type**  \nIs used to represent date and time in the required precision for clock synchronisation. It is a 64-bit unsigned fixed-point number with the integer part in the first 32 bits and the fraction part in the last 32 bits (8 Octets).  \n| DataType      | Synch_Time             |\n|---------------|------------------------|\n| Key Attribute | Code = 20              |\n| Attribute     | Size = 8 Byte          |\n| Attribute     | Number of Elements = 1 |  \n| Octet | Content                         | Comment   |\n|-------|---------------------------------|-----------|\n| 1     | Sec. since 1.1.1900             | Bit 24-31 |\n| 2     | Sec. since 1.1.1900             | Bit 16-23 |\n| 3     | Sec. since 1.1.1900             | Bit 8-15  |\n| 4     | Sec. since 1.1.1900             | Bit 0-7   |\n| 5     | Fract. Part of Sec. in 1/(2^32) | Bit 24-31 |\n| 6     | Fract. Part of Sec in 1/(2^32)  | Bit 16-23 |\n| 7     | Fract. Part of Sec in 1/(2^32)  | Bit 8-15  |'),
#  Document(metadata={'Header 1': '**4.1.1 Synch\\_Time Data Type**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='| 5     | Fract. Part of Sec. in 1/(2^32) | Bit 24-31 |\n| 6     | Fract. Part of Sec in 1/(2^32)  | Bit 16-23 |\n| 7     | Fract. Part of Sec in 1/(2^32)  | Bit 8-15  |\n| 8     | Fract. Part of Sec in 1/(2^32)  | Bit 0-7   |  \n**Table 4-1 – Format of Synch\\_Time Data Type**\n# **4.1.2 Time\\_Value Data Type**  \nThe Time\\_Value is used to represent date and time in the required precision for internal device time. It is a 63-bit unsigned fixed-point number with the integer part in the first 32 bits and the fraction part in the Following 31 bits. The last bit serves to indicate an active synchronisation and therefore a valid timestamp. This is compatible with application which do not use this Status because an error of 1 Digit is about 232 Pico second and not relevant for process view. In total (8 Octets). This is compatible with application which do not use this Status because an error of 1 Digit is about 232 Pico second and not relevant for process view.  \n| DataType      | Time_Value             |\n|---------------|------------------------|\n| Key Attribute | Code = 21              |\n| Attribute     | Size = 8 Byte          |\n| Attribute     | Number of Elements = 1 |  \n<span id="page-7-0"></span>'),
#  Document(metadata={'Header 1': '**4.1.2 Time\\_Value Data Type**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='| Key Attribute | Code = 21              |\n| Attribute     | Size = 8 Byte          |\n| Attribute     | Number of Elements = 1 |  \n<span id="page-7-0"></span>  \n| Octet | Bit | Content                         | Comment   |\n|-------|-----|---------------------------------|-----------|\n| 1     | 0-7 | Sec. since 1.1.1900             | Bit 24-31 |\n| 2     | 0-7 | Sec. since 1.1.1900             | Bit 16-23 |\n| 3     | 0-7 | Sec. since 1.1.1900             | Bit 8-15  |\n| 4     | 0-7 | Sec. since 1.1.1900             | Bit 0-7   |\n| 5     | 0-7 | Fract. Part of Sec. in 1/(2^32) | Bit 24-31 |\n| 6     | 0-7 | Fract. Part of Sec. in 1/(2^32) | Bit 16-23 |\n| 7     | 0-7 | Fract. Part of Sec. in 1/(2^32) | Bit 8-15  |\n| 8     | 1-7 | Fract. Part of Sec. in 1/(2^32) | Bit 1-7   |\n| 8     | 0   | Synch_Status                    | Bit 0     |\n#### **Table 4-2 – Format of Time\\_Value Data Type**\n# **4.1.2.1 Synch\\_Status**  \nSynch\\_Status = 0: synchronisation inactive, invalid time stamp  \nSynch\\_Status = 1: synchronisation active, valid time stamp.  \nThe Quality Code of a time stamped value is not affected by the status of time synchronisation, only the Time\\_Stamp itself.'),
#  Document(metadata={'Header 1': '**4.1.2.1 Synch\\_Status**', 'Header 4': '**4.1.2.2 Default Value of Parameters using the Time\\_Value Data Type**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='#### **4.1.2.2 Default Value of Parameters using the Time\\_Value Data Type**  \nIf there is no time synchronisation present, the device internal clock (counter) must start with the number 0x9dff440000000000 which represents the 1st of January 1984 0:00. All time stamps indicate an invalid time synchronisation (Synch\\_Status = 0).\n# **4.2 Delta\\_Trigger\\_Discrete data structure**  \nThis data structure consists of data that describes one discrete signal event, building by delta trigger mechanism. An Object of this structure is an element of Event\\_Buffer [\\(4.8\\)](#page-13-0).  \n| DataType      | Delta_Trigger_Discrete          |\n|---------------|---------------------------------|\n| Key Attribute | Code = 80                       |\n| Attribute     | Number of Elements = 7          |\n| Attribute     | Size = 14 Byte                  |\n| Attribute     | Lists of Elements (shown below) |  \n<span id="page-8-0"></span>  \n| Element | Element Name         | Data Type (code)  | Size |\n|---------|----------------------|-------------------|------|\n| 1       | Type_Of_Signal_Event | Unsigned8 - (5)   | 1    |\n| 2       | Slot                 | Unsigned8 - (5)   | 1    |\n| 3       | I/O_Channel          | Unsigned8 - (5)   | 1    |\n| 4       | Value                | Unsigned8 - (5)   | 1    |'),
#  Document(metadata={'Header 1': '**4.2 Delta\\_Trigger\\_Discrete data structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='| 2       | Slot                 | Unsigned8 - (5)   | 1    |\n| 3       | I/O_Channel          | Unsigned8 - (5)   | 1    |\n| 4       | Value                | Unsigned8 - (5)   | 1    |\n| 5       | Reserved             | Unsigned8 - (5)   | 1    |\n| 6       | Reserved             | Unsigned8 - (5)   | 1    |\n| 7       | Time_Stamp           | Time_Value - (21) | 8    |\n|         |                      |                   | 14   |\n# **Table 4-3 – Format of the Delta\\_Trigger\\_Discrete structure**\n# **4.2.1 Type\\_Of\\_Signal\\_Event**  \nType\\_Of\\_Signal\\_Event = 1 (Delta\\_Trigger\\_Discrete)\n# **4.2.2 Slot**  \nSlot and I/O\\_Channel identify the event source.\n# **4.2.3 I/O\\_Channel**  \nSlot and I/O\\_Channel identify the event source.\n# **4.2.4 Value**  \nThe Value shows the reason, because event detected.  \nBit7: Value  \nBit 7 = 1: signal is coming (correspond to parameter SIGNALFLANK)  \nBit 7 = 0: signal is going (correspond to the negation of parameter SIGNALFLANK)  \nBit 6...0: not used\n# **4.2.5 Time\\_Stamp**  \nThis element holds the time the event was happened.'),
#  Document(metadata={'Header 1': '**4.3 Time\\_Trigger\\_Discrete data structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# **4.3 Time\\_Trigger\\_Discrete data structure**  \nThis data structure consists of data that describes one discrete signal event, building by time trigger mechanism. An Object of this structure is an element of Event\\_Buffer [\\(4.8\\)](#page-13-0).  \n| DataType      | Time_Trigger_Discrete           |\n|---------------|---------------------------------|\n| Key Attribute | Code = 81                       |\n| Attribute     | Number of Elements = 7          |\n| Attribute     | Size = 14 Byte                  |\n| Attribute     | Lists of Elements (shown below) |  \n<span id="page-9-0"></span>  \n| Element | Element Name         | Data Type (code)  | Size |\n|---------|----------------------|-------------------|------|\n| 1       | Type_Of_Signal_Event | Unsigned8 - (5)   | 1    |\n| 2       | Slot                 | Unsigned8 - (5)   | 1    |\n| 3       | I/O_Channel          | Unsigned8 - (5)   | 1    |\n| 4       | Value                | Unsigned8 - (5)   | 1    |\n| 2       | Slot                 | Unsigned8 - (5)   | 1    |\n| 3       | I/O_Channel          | Unsigned8 - (5)   | 1    |\n| 4       | Value                | Unsigned8 - (5)   | 1    |\n| 5       | Reserved             | Unsigned8 - (5)   | 1    |\n| 6       | Reserved             | Unsigned8 - (5)   | 1    |\n| 7       | Time_Stamp           | Time_Value - (21) | 8    |\n|         |                      |                   | 14   |'),
#  Document(metadata={'Header 1': '**Table 4-4 – Format of the Time\\_Trigger\\_Discrete structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# **Table 4-4 – Format of the Time\\_Trigger\\_Discrete structure**\n# **4.3.1 Type\\_Of\\_Signal\\_Event**  \nType\\_Of\\_Signal\\_Event = 2 (Time\\_Trigger\\_Discrete)\n# **4.3.2 Slot**  \nSlot and I/O\\_Channel identify the event source.\n# **4.3.3 I/O\\_Channel**  \nSlot and I/O\\_Channel identify the event source.\n# **4.3.4 Value**  \nBit7: Value (signal state in this moment)  \nBit 7 = 1: signal is "1"  \nBit 7 = 0: signal is "0"  \nBit 6...0: not used\n# **4.3.5 Time\\_Stamp**  \nThis element holds the time the event was happend.\n# **4.4 Delta\\_Trigger\\_Analogue data structure**  \nThis data structure consists of data that describes one analogue signal event, building by delta trigger mechanism and relative step. An Object of this structure is an element of Event\\_Buffer ([4.8\\)](#page-13-0).  \n| DataType      | Delta_Trigger_Analogue          |\n|---------------|---------------------------------|\n| Key Attribute | Code = 82                       |\n| Attribute     | Number of Elements = 6          |\n| Attribute     | Size = 14 Byte                  |\n| Attribute     | Lists of Elements (shown below) |  \n<span id="page-10-0"></span>  \n| Element | Element Name         | Data Type (code)  | Size |\n|---------|----------------------|-------------------|------|\n| 1       | Type_Of_Signal_Event | Unsigned8 - (5)   | 1    |\n| 2       | Slot                 | Unsigned8 - (5)   | 1    |\n| 3       | I/O_Channel          | Unsigned8 - (5)   | 1    |\n| 4       | Reason               | Unsigned8 - (5)   | 1    |'),
#  Document(metadata={'Header 1': '**4.4 Delta\\_Trigger\\_Analogue data structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='| 2       | Slot                 | Unsigned8 - (5)   | 1    |\n| 3       | I/O_Channel          | Unsigned8 - (5)   | 1    |\n| 4       | Reason               | Unsigned8 - (5)   | 1    |\n| 5       | Value                | Unsigned16 - (6)  | 2    |\n| 6       | Time_Stamp           | Time_Value - (21) | 8    |\n|         |                      |                   | 14   |\n# **Table 4-5 – Format of the Delta\\_Trigger\\_Analogue structure**\n# **4.4.1 Type\\_Of\\_Signal\\_Event**  \nType\\_Of\\_Signal\\_Event = 4 (Delta\\_Trigger\\_Analogue)\n# **4.4.2 Slot**  \nSlot and I/O\\_Channel identify the event source.\n# **4.4.3 I/O\\_Channel**  \nSlot and I/O\\_Channel identify the event source.\n# **4.4.4 Reason**  \nBit7: Value change direction  \n- Bit 7 = 1: signal is rising\n- Bit 7 = 0: signal is falling  \nBit 6...0: not used\n# **4.4.5 Value**  \nThis element shows the actual value in this moment.\n# **4.4.6 Time\\_Stamp**  \nThis element holds the time the event was happend.\n# **4.5 Delta\\_Trigger\\_Analogue\\_Limit data structure**  \nThis data structure consists of data that describes one analogue signal event, building by delta trigger mechanism and absolute (critical) value. An Object of this structure is an element of Event\\_Buffer [\\(4.8\\)](#page-13-0).  \n| DataType      | Delta_Trigger_Analogue_Limit    |\n|---------------|---------------------------------|\n| Key Attribute | Code = 83                       |\n| Attribute     | Number of Elements = 6          |\n| Attribute     | Size = 14 Byte                  |\n| Attribute     | Lists of Elements (shown below) |\n|               |                                 |  \n<span id="page-11-0"></span>  \n| Element | Element Name                | Data Type (code)  | Size |\n|---------|-----------------------------|-------------------|------|\n| 1       | Type_Of_Signal_Event        | Unsigned8 - (5)   | 1    |\n| 2       | Slot                        | Unsigned8 - (5)   | 1    |'),
#  Document(metadata={'Header 1': '**4.5 Delta\\_Trigger\\_Analogue\\_Limit data structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='| 1       | Type_Of_Signal_Event        | Unsigned8 - (5)   | 1    |\n| 2       | Slot                        | Unsigned8 - (5)   | 1    |\n| 3       | I/O_Channel                 | Unsigned8 - (5)   | 1    |\n| 4       | Reason                      | Unsigned8 - (5)   | 1    |\n| 5       | Value (at time of stamping) | Unsigned16 - (6)  | 2    |\n| 6       | Time_Stamp                  | Time_Value - (21) | 8    |\n|         |                             |                   | 14   |\n# **Table 4-6 – Format of the Delta\\_Trigger\\_Analogue\\_Limit structure**\n# **4.5.1 Type\\_Of\\_Signal\\_Event**  \nType\\_Of\\_Signal\\_Event = 5 (Delta\\_Trigger\\_Analogue\\_Limit)\n# **4.5.2 Slot**  \nSlot and I/O\\_Channel identify the event source.\n# **4.5.3 I/O\\_Channel**  \nSlot and I/O\\_Channel identify the event source.\n# **4.5.4 Reason**  \nBit7: Value change direction/  \nBit 7 = 1: signal is rising  \nBit 7 = 0: signal is falling  \nBit 6...5: not used  \nBit 4: HI\\_HI-TRIGGER value reached  \nBit 4: HI-TRIGGER value reached  \nBit 4: LO-TRIGGER value reached  \nBit 4: LO\\_LO-TRIGGER value reached'),
#  Document(metadata={'Header 1': '**4.5.5 Value**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# **4.5.5 Value**  \nThis element shows the actual value in this moment.\n# **4.5.6 Time\\_Stamp**  \nThis element holds the time the event was happend.\n# **4.6 Time\\_Trigger\\_Analogue data structure**  \nThis data structure consists of data that describes one analogue signal event, building by time trigger mechanism. An Object of this structure is an element of Event\\_Buffer [\\(4.8\\)](#page-13-0).  \nDataType Time\\_Trigger\\_Analogue  \n<span id="page-12-0"></span>  \n| Key Attribute | Code = 84                       |\n|---------------|---------------------------------|\n| Attribute     | Number of Elements = 6          |\n| Attribute     | Size = 14 Byte                  |\n| Attribute     | Lists of Elements (shown below) |  \n| Element | Element Name         | Data Type (code)  | Size |\n|---------|----------------------|-------------------|------|\n| 1       | Type_Of_Signal_Event | Unsigned8 - (5)   | 1    |\n| 2       | Slot                 | Unsigned8 - (5)   | 1    |\n| 3       | I/O_Channel          | Unsigned8 - (5)   | 1    |\n| 4       | Not used = 0         | Unsigned8 - (5)   | 1    |'),
#  Document(metadata={'Header 1': '**4.6 Time\\_Trigger\\_Analogue data structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='| 2       | Slot                 | Unsigned8 - (5)   | 1    |\n| 3       | I/O_Channel          | Unsigned8 - (5)   | 1    |\n| 4       | Not used = 0         | Unsigned8 - (5)   | 1    |\n| 5       | Value                | Unsigned16 - (6)  | 2    |\n| 6       | Time_Stamp           | Time_Value - (21) | 8    |\n|         |                      |                   | 14   |\n# **Table 4-7 –Format of the Time\\_Trigger\\_Analogue structure**\n# **4.6.1 Type\\_Of\\_Signal\\_Event**  \nType\\_Of\\_Signal\\_Event = 6 (Time\\_Trigger\\_Analogue)\n# **4.6.2 Slot**  \nSlot and I/O\\_Channel identify the event source.\n# **4.6.3 I/O\\_Channel**  \nSlot and I/O\\_Channel identify the event source.\n# **4.6.4 Value**  \nThis element shows the actual value in this moment.\n# **4.6.5 Time\\_Stamp**  \nThis element holds the time the event was happened.\n# **4.7 Exception\\_Event structure**  \nThis structure consists of data that describes an exception event during time stamping process. One complete transision consist of two corresponding reports ("Coming" and "going"). An Object of this structure is an element of Event\\_Buffer [\\(4.8\\)](#page-13-0).  \n| DataType      | Exception_Event                 |\n|---------------|---------------------------------|\n| Key Attribute | Code = 85                       |\n| Attribute     | Number of Elements = 6          |\n| Attribute     | Size = 14 Byte                  |\n| Attribute     | Lists of Elements (shown below) |  \n<span id="page-13-0"></span>  \n| Element | Element Name               | Data Type (code)  | Size |\n|---------|----------------------------|-------------------|------|\n| 1       | Type_Of_Exception_Event    | Unsigned8 - (5)   | 1    |\n| 2       | Slot                       | Unsigned8 - (5)   | 1    |\n| 3       | Not used = 0               | Unsigned8 - (5)   | 1    |'),
#  Document(metadata={'Header 1': '**4.7 Exception\\_Event structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='| 2       | Slot                       | Unsigned8 - (5)   | 1    |\n| 3       | Not used = 0               | Unsigned8 - (5)   | 1    |\n| 4       | Subtype_Of_Exception_Event | Unsigned8 - (5)   | 1    |\n| 5       | Not used = 0               | Unsigned16 - (6)  | 2    |\n| 6       | Time_Stamp                 | Time_Value - (21) | 8    |\n|         |                            |                   | 14   |\n# **Table 4-8 – Format of the Exception\\_Event structure**  \n|  |  |  | 4.7.1 Type_Of_Exception_Event |  |\n|--|--|--|-------------------------------|--|\n|--|--|--|-------------------------------|--|  \n| code        | Name                   | Description                                                                                                                                                                                                                                                                                                                                                                                                                        |'),
#  Document(metadata={'Header 1': '**Table 4-8 – Format of the Exception\\_Event structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content="|-------------|------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|\n| 128         | START_THE_PROCESS      | The begin of start information of signals is indicate with this exception<br>event and subtype 1. The last signal event is following by this exception<br>event and subtype 0. All events with a timestamp between begin and end<br>of start-information-exception doesn't show a triggerevent of the<br>observed signal. This start-signal-event shows the user only the actual<br>state of the signal from time of startprocess. |\n|             |                        | The slave have to built this start information after:                                                                                                                                                                                                                                                                                                                                                                              |\n|             |                        | •<br>Start                                                                                                                                                                                                                                                                                                                                                                                                                         |"),
#  Document(metadata={'Header 1': '**Table 4-8 – Format of the Exception\\_Event structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='|             |                        | •<br>Restart                                                                                                                                                                                                                                                                                                                                                                                                                       |\n| 129,<br>130 | For further use        |                                                                                                                                                                                                                                                                                                                                                                                                                                    |\n| 131         | CLOCK_DIFFERENCE       | During processing the Timer_Clock_Message a clock difference between<br>Sync_Time and internal slave time about over 5 ms happened. (5ms is<br>the half of time-stamp-precision.) The complete information for user<br>built by the slave consists of 2 events in order with<br>subtype 1: the Time_Value is the original clock time of the slave                                                                                  |\n|             |                        | Subtype 0: the Time_Value is the Sync_Time value of the<br>synchronisation (includes correction with receiver delay factor)                                                                                                                                                                                                                                                                                                        |'),
#  Document(metadata={'Header 1': '**Table 4-8 – Format of the Exception\\_Event structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='|             |                        | The internal clock is set of the value exception event subtype 0.                                                                                                                                                                                                                                                                                                                                                                  |\n| 132         | STOP_THE_PROCESS       | The begin of Stop State of TimeStamping is shown with this exception<br>event and subtype 1. The possibility of Start TimeStamping is shown by<br>this exception-event and subtype 0. Between this two events, no signal<br>information is processing. Events with a timestamp directly after Start<br>may be from the time between begin and end of no working process.                                                           |\n|             |                        | Because of which occurence the TimeStamping process go in state<br>stop?                                                                                                                                                                                                                                                                                                                                                           |\n|             |                        | Master goes in state STOP<br>•                                                                                                                                                                                                                                                                                                                                                                                                     |'),
#  Document(metadata={'Header 1': '**Table 4-8 – Format of the Exception\\_Event structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='|             |                        | •<br>CPU goes in STOP                                                                                                                                                                                                                                                                                                                                                                                                              |\n|             |                        | •<br>DPV1-Channel breaks down (cable failure)                                                                                                                                                                                                                                                                                                                                                                                      |\n|             |                        | •<br>Other internal Slave process (may be; depends on implementation)                                                                                                                                                                                                                                                                                                                                                              |\n| 133         | BUFFER_OVERFLOW        | If all event buffers of Slave are filled, in last space of last event buffer<br>this event (with subtype 1) is placed. If one filled buffer is read by master<br>– and free for further use – this event is used with subtype 0. Between<br>this two events, no signal information is processing, all events are lost.                                                                                                             |'),
#  Document(metadata={'Header 1': '**Table 4-8 – Format of the Exception\\_Event structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content="| 134         | CHANGE_AKTIVE_STATION  | Only use for redundancy:                                                                                                                                                                                                                                                                                                                                                                                                           |\n|             |                        | The begin and the end of switch the active and passive channels of a<br>redundant slave is signed by this exception event with subtype 1 and<br>subtype 0. Between this two exception events, the timestamp-instance<br>doesn't work. No events and alarms are built. Events with a timestamp<br>directly after end of switch may be from the time between begin and end<br>of switch process.                                     |\n| 135         | REDUNDANCY_TRANSFER_FA | Only use for redundancy:                                                                                                                                                                                                                                                                                                                                                                                                           |\n|             | ILURE                  | During transfer operations between the active and the passive part of an<br>redundand slave device the component observe a failure. That means                                                                                                                                                                                                                                                                                     |"),
#  Document(metadata={'Header 1': '**Table 4-8 – Format of the Exception\\_Event structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content="|            |                       | that some information couldn't put from active to passive part.<br>Information is lost. The begin of this state is shown with the exception<br>subtype 1, the end with subtype 0. |\n|------------|-----------------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|\n| 136<br>255 | Manufacturer specific |                                                                                                                                                                                   |\n# **4.7.2 Slot**  \nSlot identifys the event source.\n# **4.7.3 Subtype\\_Of\\_Exception\\_Event**  \nThis is an additional description of exception events for further specification.  \n| Code | Name                |\n|------|---------------------|\n| 1    | Exception is coming |\n| 0    | Exception is going  |\n# **4.7.4 Time\\_Stamp**  \nTime at which the exception event took place."),
#  Document(metadata={'Header 1': '**4.8 Event\\_Buffer structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# **4.8 Event\\_Buffer structure**  \nThe Event\\_Buffer contains various discrete, analogue or exception events. The maximal number of events is 17. So it is used as a DP-V1-DataBlock (240 Byte user data).  \n| Element | Element Name  | Data Type (code)                                                                                                                                                                                                                                  | Size |\n|---------|---------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------|\n| 1       | Type_Of_Event | signal ore exception event:                                                                                                                                                                                                                       | 14   |\n|         |               | Delta_Trigger_Discrete data structure,<br>Time_Trigger_Discrete data structure,<br>Delta_Trigger_Analogue data structure,<br>Delta_Trigger_Analogue_Limit data<br>structure,<br>Time_Trigger_Analogue data structure<br>Exception_Event structure |      |\n| 2       | Type_Of_Event |                                                                                                                                                                                                                                                   | 14   |'),
#  Document(metadata={'Header 1': '**4.8 Event\\_Buffer structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='| 3       | Type_Of_Event |                                                                                                                                                                                                                                                   | 14   |\n| 4       | Type_Of_Event |                                                                                                                                                                                                                                                   | 14   |\n| 5       | Type_Of_Event |                                                                                                                                                                                                                                                   | 14   |\n|         |               |                                                                                                                                                                                                                                                   |      |\n| 17      | Type_Of_Event |                                                                                                                                                                                                                                                   | 14   |\n|         |               |                                                                                                                                                                                                                                                   | 238  |'),
#  Document(metadata={'Header 1': '**Table 4-9 –Format of Event\\_Buffer structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# **Table 4-9 –Format of Event\\_Buffer structure**\n# **4.8.1 Type\\_Of\\_Event**  \n| Type_Of_Event = | 1 | Delta_Trigger_Discrete data structure (4.2)       |\n|-----------------|---|---------------------------------------------------|\n|                 | 2 | Time_Trigger_Discrete data structure (4.3)        |\n|                 | 4 | Delta_Trigger_Analogue data structure (4.4)       |\n|                 | 5 | Delta_Trigger_Analogue_Limit data structure (4.5) |\n|                 | 6 | Time_Trigger_Analogue data structure (4.6)        |\n|                 |   |                                                   |  \n128... Exception\\_Event structure (4.7)\n## <span id="page-15-0"></span>**4.9 Event\\_Buffer\\_Acknowledge structure**  \nThe Event\\_Buffer\\_Acknowledge is used as an user-host-application-acknowledge of data transport. So the slave knows that the Data Set Read-mechanism ended and the complete date are processed in host. To each event buffer exist a corresponding event buffer acknowledge.  \n| Element | Element Name       | Data Type (code) | Size |\n|---------|--------------------|------------------|------|\n| 1       | Acknowledge_Status | Unsigned16 - (6) | 2    |\n|         |                    |                  | 2    |'),
#  Document(metadata={'Header 1': '**4.8.1 Type\\_Of\\_Event**', 'Header 2': '<span id="page-15-0"></span>**4.9 Event\\_Buffer\\_Acknowledge structure**', 'Header 4': '**Table 4-10 – Format of Event\\_Buffer\\_Acknowledge structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='#### **Table 4-10 – Format of Event\\_Buffer\\_Acknowledge structure**\n#### **4.9.1 Acknowledge\\_Status**  \nUser defined (depends on special application)\n#### **4.10 Alarm Summery Structure**  \nThis data structure consists of data that summarize 16 alert types  \n| DataType      | Alarm Summary                   |\n|---------------|---------------------------------|\n| Key Attribute | Code = 42                       |\n| Attribute     | Number of Elements = 4          |\n| Attribute     | Size = 8 Byte                   |\n| Attribute     | Lists of Elements (shown below) |  \n| Element | Element Name   | Data Type (code)    | Size |\n|---------|----------------|---------------------|------|\n| 1       | Current        | Octet String - (10) | 2    |\n| 2       | Unacknowledged | Octet String - (10) | 2    |\n| 3       | Unreported     | Octet String - (10) | 2    |\n| 4       | Disabled       | Octet String - (10) | 2    |  \n```\nTable 4-11 – Format of the Alarm Summary structure\n```\nBits of the Octet String are associated with the following alarms:'),
#  Document(metadata={'Header 1': 'Octet 0', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# Octet 0  \n0 = Discrete alarm (LSB) (only Function Blocks with discrete or integer limit parameters)  \n1 = HI\\_HI\\_Alarm (only Function Blocks with analog limit parameters)  \n2 = HI\\_Alarm (only Function Blocks with analog limit parameters)  \n3 = LO\\_LO\\_Alarm (only Function Blocks with analog limit parameters)  \n4 = LO\\_Alarm (only Function Blocks with analog limit parameters)  \n5 = Zero (only Function Blocks with discrete or integer limit parameters)  \n- 6 = Simulation\n- Copyright by PNO 2001 All rights reserved. Page 16  \n<span id="page-16-0"></span>7 = Update Event  \nOctet 1  \n- 0 = Fail Safe\n- 1 = Access Protection\n- 2 = Diagnosis Alarm\n- 3 = Extended Diagnosis Alarm\n- 4 = Checkback Alarm\n- 5 = Defect Alarm\n- 6 = reserved\n- 7 = reserved  \n| Octet 0 |       | Octet 1 |       |\n|---------|-------|---------|-------|\n| Bit 7   | Bit 0 | Bit 7   | Bit 0 |  \n| Current        | Alarm bits will be set to 1 or 0 if the alarm reason occurs (1) or is gone (0).         |  |\n|---------|-------|---------|-------|\n| Bit 7   | Bit 0 | Bit 7   | Bit 0 |  \n| Current        | Alarm bits will be set to 1 or 0 if the alarm reason occurs (1) or is gone (0).         |  |\n|----------------|-----------------------------------------------------------------------------------------|--|\n|                | The update event bit will be set to 1 after ST_REV increment or other problems          |  |\n| Unreported     | Bits will be set to 0 if the incident is reported by alarm mechanism.                   |  |\n| Unacknowledged | Bits will be set to 0 if the alarm is acknowledged.                                     |  |\n| Disabled       | Set to 1, if the responding enable parameter DPV1_Status_2 and ALERT_ENABLE<br>is false |  |'),
#  Document(metadata={'Header 1': '**4.11 Trend\\_Float Structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# **4.11 Trend\\_Float Structure**  \nThis data structure consists of data that describes the floating point trend data. An Object of this structure is like a buffer, that contains sampled floating point data accompanied with a status.  \n| DataType      | Trend_Float                     |\n|---------------|---------------------------------|\n| Key Attribute | Code = 46                       |\n| Attribute     | Number of Elements = 37         |\n| Attribute     | Size = 97 Byte                  |\n| Attribute     | Lists of Elements (shown below) |\n|               |                                 |  \n| Element | Element Name             | Data Type (code)  | Size |\n|---------|--------------------------|-------------------|------|\n| 1       | Block_Index              | Unsigned16 - (6)  | 2    |\n| 2       | Parameter_Relative_Index | Unsigned16 - (6)  | 2    |\n| 3       | Sample_Type              | Unsigned8 - (5)   | 1    |\n| 4       | Sample_Interval          | Float - (8)       | 4    |\n| 2       | Parameter_Relative_Index | Unsigned16 - (6)  | 2    |\n| 3       | Sample_Type              | Unsigned8 - (5)   | 1    |\n| 4       | Sample_Interval          | Float - (8)       | 4    |\n| 5       | Last_Update              | Time_Value - (21) | 8    |\n| 6 – 21  | 16_Samples_Values        | Float - (8)       | 64   |\n| 22 – 37 | 16_Samples_Status        | Unsigned8 - (5)   | 16   |  \n**Table 4-12 – Format of the Trend\\_Float structure**'),
#  Document(metadata={'Header 1': '<span id="page-17-0"></span>**4.11.1 Block\\_Index**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='# <span id="page-17-0"></span>**4.11.1 Block\\_Index**  \nBlock\\_Index has the meaning of Slot\n# **4.11.2 Parameter\\_Relative\\_Index**  \nParameter\\_Relative\\_Index here it has the meaning Absolute\\_Index\n## **4.11.3 Sample\\_Type**  \nSample Type\n#### **4.11.4 Sample\\_Interval**  \nContains the time difference between two samples in seconds, equidistant sampling provided.\n#### **4.11.5 Last\\_Update**  \nThis element contains the Time\\_Stamp of the last sampled value.\n#### **4.11.6 16\\_Samples\\_Values**  \nThis array of floating point values is filled with the sampled values. The lowest index of the array carries the oldest sample.\n#### **4.11.7 16\\_Samples\\_Status**  \nThis array is filled with the status according to the sampled value. The lowest index of the array carries the oldest sample.\n#### **4.12 Trend\\_Float\\_Unequidistant Structure**  \nThis data structure consists of data that describes the floating point trend data. An Object of this structure is like a buffer, that contains sampled floating point data accompanied with a status and a timestamp. This structure is used if the sampling does not start in equidistant intervals.  \n| DataType      | Trend_Float_Unequidistant       |\n|---------------|---------------------------------|\n| Key Attribute | Code = 97                       |\n| Attribute     | Number of Elements = 35         |\n| Attribute     | Size = 211 Byte                 |\n| Attribute     | Lists of Elements (shown below) |  \n| Element | Element Name      | Data Type (code)                     | Size |\n|---------|-------------------|--------------------------------------|------|\n| 1       | Slot              | Unsigned8 - (5)                      | 1    |\n| 2       | Index             | Unsigned8 - (5)                      | 1    |'),
#  Document(metadata={'Header 1': '**4.11.2 Parameter\\_Relative\\_Index**', 'Header 2': '**4.11.3 Sample\\_Type**', 'Header 4': '**4.12 Trend\\_Float\\_Unequidistant Structure**', 'name_file': 'Time_Stamp_2192_V10_Jul01'}, page_content='| 1       | Slot              | Unsigned8 - (5)                      | 1    |\n| 2       | Index             | Unsigned8 - (5)                      | 1    |\n| 3       | Sample_Type       | Unsigned8 - (5)                      | 1    |\n| 4 – 19  | 16_Samples_Values | Value & Status Floating Point – (33) | 80   |\n| 20 – 35 | 16_Timestamps     | Time_Value - (21)                    | 128  |  \n| Table 4-13 – Format of the Trend_Float_Unequidistant structure |  |\n|----------------------------------------------------------------|--|\n|                                                                |  |\n# <span id="page-18-0"></span>**4.12.1 Slot**  \nSlot of the parameter, which is sampled\n# **4.12.2 Index**  \nAbsolute\\_Index of the parameter, which is sampled\n# **4.12.3 Sample\\_Type**  \nSample Type\n# **4.12.4 16\\_Samples\\_Values**  \nThis array of floating point values is filled with the sampled values including the status. The lowest index of the array carries the oldest sample.\n# **4.12.5 16\\_Timestamps**  \nThis array is filled with the timestamp according to the sampled value. The lowest index of the array carries the oldest timestamp of the oldest sample.'),
# ...
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**CREP**', 'Header 3': '**Result(+)**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='### **Result(+)**  \nThis selection type parameter indicates that the service request succeeded.\n### **List of Diag Data**  \nThis parameter is composed of the following list elements:\n### **Prm Req**  \nThis parameter contains the value of the attribute Prm Req of the MS0 ARL entry of a DP-slave.\n## **Prm Fault**  \nThis parameter contains the value of the attribute Prm Fault of the MS0 ARL entry of a DP-slave.\n### **Cfg Fault**  \nThis parameter contains the value of the attribute Cfg Fault of the MS0 ARL entry of a DP-slave.\n### **Not Supported**  \nThis parameter contains the value of the attribute Not Supported of the MS0 ARL entry of a DP-slave.\n### **Station Not Ready**  \nThis parameter contains the value of the attribute Station Not Ready of the MS0 ARL entry of a DP-slave.\n### **Stat Diag**  \nThis parameter contains the value of the attribute Stat Diag of the MS0 ARL entry of a DP-slave.\n### **WD On**  \nThis parameter contains the value of the attribute WD On of the MS0 ARL entry of a DP-slave.'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Prm Fault**', 'Header 3': '**WD On**', 'Header 4': '**Sync Mode**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='#### **Sync Mode**  \nThis parameter contains the value of the attribute Sync Mode of the MS0 ARL entry of a DP-slave.\n## **Freeze Mode**  \nThis parameter contains the value of the attribute Freeze Mode of the MS0 ARL entry of a DP-slave.\n## **Master Add**  \nThis parameter contains the value of the attribute Master Add of the MS0 ARL entry of a DP-slave.\n### **Ident Number**  \nThis parameter contains the value of the attribute Ident Number of the MS0 ARL entry of a DP-slave.\n### **Deactivated**  \nThis parameter contains the value of the attribute Deactivated of the of the related CRL entry of the correspondent DP-slave of the DP-master (Class 1).\n### **Station Non Existent**  \nThis parameter contains the value of the attribute Station Non Existent of the related CRL entry of the correspondent DP-slave of the DP-master (Class 1).\n### **Invalid Slave Response**  \nThis parameter contains the value of the attribute Invalid Slave Response of the related CRL entry of the correspondent DP-slave of the DP-master (Class 1).'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Master Add**', 'Header 3': '**Master Lock**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='### **Master Lock**  \nThis parameter indicates whether the DP-slave is locked by a DP-master. If the Master Lock parameter is TRUE the DP-slave is locked by another DP-master. If the parameter is False the DP-slave is not locked by another DP-master (Class 1).\n### **Ext Diag Overflow**  \nThis Boolean parameter contains the value of the parameter Ext Diag Overflow of the Set Slave Diag service if not all delivered values of the Diagnosis objects are contained in this service confirmation. This parameter contains the value of the attribute Ext Diag Overflow of the related CRL entry of the correspondent DP-slave of the DP-master (Class 1) if not all delivered values of the Diagnosis objects are contained in this service confirmation due to storage problems.  \nAttribute Type: Boolean  \nAllowed values: TRUE, FALSE  \nNOTE In case of an overflow condition it is allowed to truncate only at Diagnosis object limits.\n### **Ext Diag Flag**  \nThis parameter contains the value of the parameter Ext Diag Flag of the Set Slave Diag service of a DP-slave.'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Master Add**', 'Header 3': '**Ext Diag Data**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='### **Ext Diag Data**  \nThis parameter is composed of the following subparameters:\n#### **Device Related Diagnosis Data**  \nThis parameter contains the value of the Device Related Diagnosis object of a DPslave.\n#### **List of Identifier Status**  \nThis parameter is composed of the following list elements:\n#### **Identifier Status**  \nThis parameter contains the value of the attribute Identifier Status of the Identifier Related Diagnosis object of a DP-slave.\n#### **List of Channel Related Diagnosis Data**  \nThis parameter is composed of the following list elements:\n## **Identifier Number**  \nThis parameter contains the value of the attribute Identifier Number of one Channel Related Diagnosis object of a DP-slave.\n### **Channel Number**  \nThis parameter contains the value of the attribute Channel Number of one Channel Related Diagnosis object of a DP-slave.\n### **Channel Type**  \nThis parameter contains the value of the attribute Channel Type of one Channel Related Diagnosis object of a DP-slave.'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Identifier Number**', 'Header 3': '**Channel Type**', 'Header 4': '**IO Type**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='#### **IO Type**  \nThis parameter contains the value of the attribute IO Type of one Channel Related Diagnosis object of a DP-slave.\n#### **Error Type**  \nThis parameter contains the value of the attribute Error Type of one Channel Related Diagnosis object of a DP-slave.\n### **List of Status Data**  \nThis parameter is composed of the following list elements:\n#### **Slot Number**  \nThis parameter contains the value of the attribute Slot Number of one Status object of a DP-slave.\n#### **Status Type**  \nThis parameter contains the value of the attribute Status Type of one Status object of a DP-slave.\n#### **Status Specifier**  \nThis parameter contains the value of the attribute Status Specifier of one Status object of a DP-slave.\n#### **Status Data**  \nThis parameter contains the value of one Status object of a DP-slave.\n#### **Module Status Data**  \nThis parameter is composed of the following subparameters:\n#### **Status Specifier**  \nThis parameter contains the value of the attribute Status Specifier of the Module Status Data object of a DP-slave.'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Identifier Number**', 'Header 3': '**List of Status Data**', 'Header 4': '**List of Module Status**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='#### **List of Module Status**  \nThis parameter is composed of the following list elements:\n#### **Module Status**  \nThis parameter contains the value of the attribute Module Status of the Module Status Data object of a DP-slave.\n#### **DXB-Link Status**  \nThis parameter is composed of the following subparameters:\n#### **Status Specifier**  \nThis parameter contains the value of the attribute Status Specifier of the DXB-Link Status object of a DP-slave.\n#### **List of DXB-Link Status**  \nThis parameter is composed of the following list elements:\n### **Publisher Address**  \nThis parameter contains the value of the attribute Publisher Address of the DXB-Link Status object of a DP-slave.\n#### **Link Status**  \nThis parameter contains the value of the attribute Link Status of the DXB-Link Status object of a DP-slave.\n#### **Link Error**  \nThis parameter contains the value of the attribute Link Error of the DXB-Link Status object of a DP-slave.\n#### **Red Diagnosis**  \nThis parameter is composed of the following subparameters:'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Identifier Number**', 'Header 3': '**Publisher Address**', 'Header 4': '**Red Status**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='#### **Red Status**  \nThis selection type parameter indicates that the parameter Red Diagnosis contains the diagnosis information of the redundant communication interfaces of a redundant DP-Slave. This parameter is composed of the following subparameters:\n#### **Seq Number**  \nThis parameter contains the Sequence Number necessary for the unique identification of the received Red Status.  \nAllowed values: 0 to 31\n#### **Function**  \nThis parameter is composed of the following subparameters:\n#### **Primary Request**  \nThis Boolean parameter set to TRUE indicates that a Primary Request was executed at this communication interface. This parameter set to FALSE indicates that no Primary Request was executed at this communication interface.  \nAllowed values: TRUE, FALSE\n#### **MS1 Command**  \nThis parameter indicates if a MS1 Command like Start MS1, Stop MS1, Reset MS1 or no MS1 Command was executed at this communication interface.  \nAllowed values: Start MS1, Stop MS1, Reset MS1, no Action\n#### **Check Properties**  \nThis Boolean parameter set to TRUE indicates that a Check Properties request was executed at this communication interface. This parameter set to FALSE indicates that no Check Properties request was executed at this communication interface.  \nAllowed values: TRUE, FALSE'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Identifier Number**', 'Header 3': '**Publisher Address**', 'Header 4': '**Master State Clear**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='#### **Master State Clear**  \nThis Boolean parameter set to TRUE indicates that the related DP-Master (Class 1) have set the communication interface in the state Clear. This parameter set to FALSE indicates that the related DP-Master (Class 1) have sent no Master State Clear command.  \nAllowed values: TRUE, FALSE\n### **Red Status1**  \nThis parameter contains the redundancy status of the first communication interface of a redundant DP-Slave. This parameter is composed of the following subparameters:\n### **Role**  \nThis parameter set to Primary indicates that this communication interface acts as the primary interface. This parameter set to Backup indicates that this communication interface acts as the Backup interface. This parameter set to Power On indicates that the assignment of the roles between the two communication interfaces is not finished yet (e. g. at Power On of the DP-Slave).  \nAllowed values: Primary, Backup, Power On\n#### **HW Defect**  \nThis Boolean parameter set to TRUE indicates that an HW Defect of this communication interface has been detected.  \nAllowed values: TRUE, FALSE'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Identifier Number**', 'Header 3': '**Role**', 'Header 4': '**Data Exchange**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='#### **Data Exchange**  \nThis Boolean parameter set to TRUE indicates that this communication interface is in the data exchange state.  \nAllowed values: TRUE, FALSE\n#### **Safe State**  \nThis Boolean parameter set to TRUE indicates that this communication interface is in the Fail Safe state.  \nAllowed values: TRUE, FALSE\n### **DL Initialised**  \nThis Boolean parameter set to TRUE indicates that the DL parameter of this communication interface has been loaded.  \nAllowed values: TRUE, FALSE\n#### **TOH started**  \nThis Boolean parameter set to TRUE indicates that the Output Hold Timer of this communication interface has been started.  \nAllowed values: TRUE, FALSE\n#### **Red Status2**  \nThis parameter contains the redundancy status of the second (redundant) communication interface of a redundant DP-Slave. This parameter is composed of the following subparameters:\n#### **Role**  \nThis parameter set to Primary indicates that the other communication interface acts as the primary interface. This parameter set to Backup indicates that the other communication interface acts as the Backup interface. This parameter set to Power On indicates that the assignment of the roles between the two communication interfaces is not finished yet ( e. g. at Power On of the DP-Slave).  \nAllowed values: Primary, Backup, Power On'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Identifier Number**', 'Header 3': '**DL Initialised**', 'Header 4': '**HW Defect**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='#### **HW Defect**  \nThis Boolean parameter set to TRUE indicates that an HW Defect of the other communication interface has been detected.  \nAllowed values: TRUE, FALSE\n### **Data Exchange**  \nThis Boolean parameter set to TRUE indicates that the other communication interface is in the data exchange state.  \nAllowed values: TRUE, FALSE\n#### **Safe State**  \nThis Boolean parameter set to TRUE indicates that the other communication interface is in the Fail Safe state.  \nAllowed values: TRUE, FALSE\n#### **DL Initialised**  \nThis Boolean parameter set to TRUE indicates that the DL parameter of the other communication interface has been loaded.  \nAllowed values: TRUE, FALSE\n#### **TOH started**  \nThis Boolean parameter set to TRUE indicates that the Output Hold Timer of this communication interface has been started.  \nAllowed values: TRUE, FALSE\n#### **Prm Command Ack**  \nThis selection type parameter indicates that the parameter Red Diagnosis contains the acknowledgment of a previously received Prm Command. This parameter is composed of the following subparameters:'),
#  Document(metadata={'Header 1': '**TMAPC, TSAPC (Master Application Cycle Time, Slave Application Cycle Time)**', 'Header 2': '**Identifier Number**', 'Header 3': '**Data Exchange**', 'Header 4': '**Seq Number**', 'name_file': 'iec61158-5-3{ed3.0}b'}, page_content='#### **Seq Number**  \nThis parameter contains the Sequence Number necessary for the unique identification of the received Prm Command Ack.  \nAllowed values: 0 to 31\n#### **Function**  \nThis parameter is composed of the following subparameters:\n#### **Primary Request**  \nThis Boolean parameter set to TRUE indicates that a Primary Request was executed at this communication interface. This parameter set to FALSE indicates that no Primary Request was executed at this communication interface.  \nAllowed values: TRUE, FALSE\n#### **MS1 Command**  \nThis parameter indicates if a MS1 Command like Start MS1, Stop MS1, Reset MS1 or no MS1 Command was executed at this communication interface.  \nAllowed values: Start MS1, Stop MS1, Reset MS1, no Action\n#### **Check Properties**  \nThis Boolean parameter set to TRUE indicates that a Check Properties request was executed at this communication interface. This parameter set to FALSE indicates that no Check Properties request was executed at this communication interface.  \nAllowed values: TRUE, FALSE'),
#  ...]

# %% [markdown]
# # **RAG**

# %%
from langchain_ollama import OllamaEmbeddings
from langchain_community.vectorstores.faiss import FAISS
from langchain_ollama import ChatOllama
from typing_extensions import TypedDict
from typing import List
from langchain.schema import Document
from langchain.retrievers.multi_query import MultiQueryRetriever
from langchain_core.output_parsers import BaseOutputParser
from langchain_core.prompts import PromptTemplate
from pydantic import BaseModel, Field
from langgraph.graph import START, StateGraph
from IPython.display import Image, display
from pprint import pprint
from langchain_core.prompts import ChatPromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.embeddings import OpenAIEmbeddings

# %%
# Example embeddings (you can use OpenAIEmbeddings or another)
embeddings = OllamaEmbeddings(model="nomic-embed-text:latest")

# Create an in-memory local vector store (FAISS)
vector_store = FAISS.from_documents(merged_documents, embedding=embeddings)

# %%
# vector_store.save_local("faiss_index")

# %%
# # Example embeddings (you can use OpenAIEmbeddings or another)
# embeddings = OllamaEmbeddings(model="nomic-embed-text:latest")
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")

# # Create an in-memory local vector store (FAISS)
# vector_store = FAISS.from_documents(splits, embedding=embeddings)

# vector_store.save_local("faiss_index")

# %%
vector_store = FAISS.load_local("faiss_index", embeddings, allow_dangerous_deserialization=True)

# %%
# Example of an LLM
# llm = ChatOllama(temperature=0, model="gemma3:12b")

llm = ChatOpenAI(temperature=0, model="gpt-4o-mini")

# %%
template = """You are an AI language model assistant that understands PROFIBUS-related documents and specifications in the context of industrial automation.

IMPORTANT: FOCUS **ONLY ON PROFIBUS**.  
DO NOT INCLUDE **ANYTHING** ABOUT PROFINET.  
DO NOT INCLUDE **ANYTHING** ABOUT CANOPEN.  
THIS IS **ONLY** ABOUT PROFIBUS.  
REPEAT: **PROFIBUS ONLY**.  
IGNORE ALL OTHER PROTOCOLS.

### Instructions:
- Answer in a clear, informative, and technically accurate manner.
- Provide a **complete and relevant explanation**, but avoid excessive detail.
- Start with a **direct answer**, then expand with useful clarification, examples, or context if appropriate.
- Avoid unnecessary filler or repetition.
- Answer **in the same language as the question**.
- You can say "I don't know" if you don't know the answer.

### Now answer the following:

Question: {question}

Context: {context}

Answer (in the language of the question):  
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
question = "Qual é o objetivo de um dispositivo Linking na integração de CANopen com PROFINET IO?"

# %%
def generate_hypothetical_document(question: str) -> str:
    """
    Generates a hypothetical, technically accurate document in English for the given question,
    to be used in vector-based retrieval systems. The result must be focused, factual, and domain-specific.
    """
    hyde_template = (
        "You are an AI language model assistant that understands PROFIBUS-related documents and specifications in the context of industrial automation. "
        "Your task is to generate a detailed and technically accurate hypothetical answer that could appear in a knowledge base, "
        "technical documentation, or white paper related to industrial networking. Follow these strict instructions:\n"
        "1. The response must ONLY contain the hypothetical document text—no commentary, notes, explanations, or formatting.\n"
        "2. The content must be written in English and must not include greetings or apologies.\n"
        "3. The text should be informative, concise, and focused on answering the question using domain-relevant terminology.\n"
        "4. Do not restate the question. Just provide the content.\n\n"
        "Question: {question}\n\n"
        "Hypothetical Document:"
    )

    prompt_hyde = ChatPromptTemplate.from_template(hyde_template)
    messages = prompt_hyde.format(question=question)

    # hyde_llm = ChatOllama(model="gemma3:12b", temperature=0.7)
    hyde_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)

    # Generate the hypothetical document
    response = hyde_llm.invoke(messages)

    # Extract and clean content
    if hasattr(response, "content"):
        return response.content.strip()
    else:
        return response.strip()

# %%
generate_hypothetical_document(question)
# Out:
# 'The Linking Device serves a critical role in the integration of CANopen networks with PROFINET IO systems, facilitating seamless communication between the two different protocols. Its primary objective is to act as a bridge that translates CANopen messages into PROFINET IO frames and vice versa, ensuring interoperability between devices operating under these distinct communication standards. \n\nThis device typically handles the necessary protocol conversions, managing data mapping and the synchronization of communication cycles to maintain real-time performance. By leveraging the Linking Device, users can incorporate CANopen devices into a PROFINET IO environment without the need for extensive modifications to existing infrastructure, thus preserving investment in legacy systems while enabling access to the advanced features offered by PROFINET IO, such as improved diagnostics and higher bandwidth.\n\nAdditionally, the Linking Device can provide configuration options to manage the relationship between the CANopen and PROFINET IO networks, allowing for the customization of data exchange parameters, such as the frequency of data updates and the handling of network errors. Overall, the Linking Device is essential for creating a cohesive industrial automation solution that integrates diverse fieldbus technologies efficiently.'

# %%
retriever = vector_store.as_retriever()

# %%
class State(TypedDict):
    question: str           # User's question
    hypothetical_answer: str # Hypothetical document generated for retrieval
    context: List[Document] # Documents returned by the retrieve function
    answer: str             # Final answer from the LLM

def generate_hypothetical_document(question: str) -> str:
    """
    Generates an ideal hypothetical answer for the given question to be used for document retrieval.
    The answer must be solely the hypothetical document, with no additional commentary, explanations, or formatting.
    """
    hyde_template = (
        "You are an expert assistant. Given the following question, generate a comprehensive hypothetical answer "
        "that will serve as an ideal document for information retrieval. Follow these strict rules:\n"
        "1. Do not include any extra commentary, headers, or notes. Your response must be only the hypothetical document text.\n"
        "2. Do not include greetings, apologies, or any text before or after the answer.\n"
        "3. The answer should be concise, factual, and focused solely on answering the question.\n\n"
        "Question: {question}\n\n"
        
        "Hypothetical Answer (in english. ONLY the text, nothing else):"
    )
    prompt_hyde = ChatPromptTemplate.from_template(hyde_template)
    messages = prompt_hyde.format(question=question)

    # hyde_llm = ChatOllama(model="gemma3:12b", temperature=0.7)
    hyde_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)
    
    # Utilize the LLM to generate the hypothetical document.
    response = hyde_llm.invoke(messages)
    
    # If the response is wrapped in an AI message, extract its content.
    if hasattr(response, "content"):
        return {"hypothetical_answer": response.content.strip()}
    else:
        return {"hypothetical_answer": response.strip()}

def retrieve(state: State):
    """
    Retrieval step: performs a similarity search in the vector_store
    and returns the documents that will serve as context for the answer.
    
    Args:
        state (State): The current state containing the user's question.
    
    Returns:
        dict: A dictionary with the key "context" that will be added to the state.
    """
    retrieved_docs = retriever.invoke(state["hypothetical_answer"])
    # Returns a dictionary with the key "context"
    return {"context": retrieved_docs}

def generate(state: State):
    """
    Generation step: formats the 'context' and the 'question' into a prompt,
    calls the LLM, and obtains the final answer.
    
    Args:
        state (State): The current state containing the user's question and the retrieved context.
    
    Returns:
        dict: A dictionary with the key "answer" containing the final answer from the LLM.
    
    Raises:
        ValueError: If the response format from the LLM is unexpected.
    """
    docs_content = "\n\n".join(doc.page_content for doc in state["context"])
    messages = prompt.invoke({"question": state["question"], "context": docs_content})
    
    response = llm.invoke(messages)  # or llm(messages), depending on your setup

    # If the response is of type AIMessage and has the attribute 'content', use it:
    if hasattr(response, "content"):
        return {"answer": response.content}
    elif isinstance(response, str):
        return {"answer": response}
    else:
        raise ValueError("Unexpected response format.")

# %%
# Build the application graph:
graph_builder = StateGraph(State).add_sequence([generate_hypothetical_document, retrieve, generate])
graph_builder.add_edge(START, "generate_hypothetical_document")
graph_builder.add_edge("generate_hypothetical_document", "retrieve")
graph_builder.add_edge("retrieve", "generate")

# Compile into a callable "graph" object
graph = graph_builder.compile()

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## **Queries**

# %%
import re
from pprint import pprint

def clean_answer(answer: str) -> str:
    """
    Cleans the generated answer by removing unnecessary information and formatting.
    
    Args:
        answer (str): The raw answer generated by the LLM.
        
    Returns:
        str: The cleaned answer, formatted for better readability.
    """

    # Remove logs such as INFO:langchain...
    cleaned = re.sub(r'INFO:.*?(\n|$)', '', answer)

    # Extract the value of the 'answer' key if it's a dictionary string
    match = re.search(r"'answer':\s*([\"'])(.*?)\1", cleaned, re.DOTALL)
    if match:
        cleaned = match.group(2)

    # Remove markdown bold formatting **text**
    cleaned = re.sub(r"\*\*(.*?)\*\*", r"\1", cleaned)

    # Remove duplicate spaces and normalize line breaks
    cleaned = re.sub(r'\n{3,}', '\n\n', cleaned)
    cleaned = re.sub(r'[ \t]+$', '', cleaned, flags=re.MULTILINE)

    return cleaned.strip()

def clean_context(context):
    """
    Simplifies the context by extracting relevant metadata and limiting content length.
    
    Args:
        context (List[Document]): The list of documents retrieved as context.
        
    Returns:
        List[dict]: A simplified list of dictionaries containing the document ID and a snippet of the content.
    """
    
    return [
        {
            "id": doc.metadata.get("name_file", doc.metadata.get("source", "unknown")),
            "content": doc.page_content[:300] + "..." if len(doc.page_content) > 300 else doc.page_content
        }
        for doc in context
    ]

def process_question(question: str):
    """
    Process a user's question by retrieving context and generating an answer using the graph.

    Args:
        question (str): The user's question.

    Prints:
        The retrieved context and the generated answer.
    """
    for step_result in graph.stream({"question": question}, stream_mode="updates"):
        if "retrieve" in step_result:
            context = step_result.get("retrieve", {}).get("context", [])
            simplified_context = clean_context(context)
            print("\n📚 Retrieved Context:\n")
            pprint(simplified_context)

        if "generate" in step_result:
            raw_answer = step_result.get("generate", {}).get("answer", "")
            formatted_answer = clean_answer(raw_answer)
            print("\n🧠 Generated Answer:\n")
            print(formatted_answer)

# %% [markdown]
# ### 1 - What is a GSD file, where can you get it, and what is its function?

# %%
question_1 = "What is a GSD file, where can you get it, and what is its function?"
process_question(question_1)
# Out:
# 📚 Retrieved Context:
#
# [{'content': '• General specifications  \n'
#              'This section contains information on vendor and device names, '
#              'hardware and software release states, baud rates supported, '
#              'possible time intervals for monitoring times and the signal '
#              'assignment on the bus connector.  \n'
#              '• Master-related specifications  \n'
#              'This section contains ...',
#   'id': 'Copia di iec61784-1{ed4.0}b'},
#  {'content': 'After the adjustment of the F-Parameters during network '
#              'configuration, an F-Parameter record is compiled and stored '
#              'within the F-Host/IO-controller for start-up of the network.  \n'
#              'The F-Parameter "F\\_IO\\_StructureDescCRC" is used to ensure '
#              'correct usage of the F-I/O data structure and data types by t...',
#   'id': 'Copia di iec61784-3-3{ed2.0}en'},
#  {'content': '- Fiber Optic for improved interference immunity and large '
#              'network distances. The following MAU are specified:\n'
#              '- Glass Multi mode fiber and Single mode fiber\n'
#              '- Plastic fiber\n'
#              '- PCF Fiber  \n'
#              'Copper & Power based on synchronous transmission for use in '
#              'intrinsic / non intrinsic safety area and with the o...',
#   'id': 'Copia di iec61784-1{ed4.0}b'},
#  {'content': '• Spécifications générales  \n'
#              'Cette partie contient des informations concernant les noms des '
#              'fournisseurs et des appareils, les versions de matériels et de '
#              'logiciels, les débits en bauds pris en charge, les intervalles '
#              'de temps possibles pour la surveillance temporelle et '
#              "l'attribution des signaux su...",
#   'id': 'Copia di iec61784-1{ed4.0}b'}]
#
# 🧠 Generated Answer:
#
# A GSD file, or General Station Description file, is a crucial component in the PROFIBUS protocol that provides detailed information about a PROFIBUS device. It contains specifications such as vendor and device names, supported baud rates, I/O channel configurations, and diagnostic information. The GSD file is structured to facilitate the integration and configuration of devices from different manufacturers within a PROFIBUS network, enabling a Plug and Play experience.
#
# You can obtain GSD files from the device manufacturer’s website or through PROFIBUS user organizations. They are typically provided as part of the device documentation or can be downloaded directly from the manufacturer's support pages.
#
# The primary function of a GSD file is to allow configuration tools and network management software to understand the capabilities and requirements of the PROFIBUS devices. This includes defining mandatory parameters (like Vendor_Name) and optional parameters (like Sync_Mode_supported), which help in setting up the network correctly and ensuring that devices communicate effectively. The GSD file's flexibility allows it to accommodate various device types and configurations, making it essential for successful PROFIBUS network implementation.

# %% [markdown]
# ### 2 - What is a token message and how and which devices use it?

# %%
question_2 = "What is a token message and how and which devices use it?"
process_question(question_2)
# Out:
# 📚 Retrieved Context:
#
# [{'content': 'a) Token-passing allows fair media access for all token '
#              'holders.  \n'
#              'EXAMPLE When four token holders produce the same amount of '
#              'similar priority data they will share the media so that on '
#              'average each of them can use 25 % of the available message '
#              'transfer time. With the token-passing procedure, rules e...',
#   'id': 'Copia di iec61158-4-3{ed3.0}b'},
#  {'content': 'P-NET can handle up to 300 confirmed data transactions per '
#              'second, from 300 independent addresses. Data can be transferred '
#              'in the form of fully processed values (floating point), such as '
#              'temperature, pressure etc., or as for example blocks of 32 '
#              'independent binary signals, indicating valve states, s...',
#   'id': 'Copia di iec61784-1{ed4.0}b'},
#  {'content': 'Medium access control may be exercised by each master station '
#              '(active station) if the station has the token. The token is '
#              'passed from master station to master station in a logical ring '
#              'and thus determines the instant, when a master station may '
#              'access the medium. Controlled token passing is managed b...',
#   'id': 'Copia di iec61158-4-3{ed3.0}b'},
#  {'content': '#### **5.3.2 Token procedures**\n'
#              '### **5.3.2.1 Token circulation**  \n'
#              'The token is passed from master station to master station in '
#              'ascending numerical order of station addresses by means of the '
#              'token DLPDU (see 7.4). To close the logical token ring, the '
#              'station with the highest address passes the toke...',
#   'id': 'Copia di iec61158-4-3{ed3.0}b'}]
#
# 🧠 Generated Answer:
#
# A token message in the context of PROFIBUS refers to a specific type of message used in the token-passing mechanism for medium access control among master stations in a PROFIBUS network. This mechanism ensures that only one master station can transmit data at a time, thereby preventing collisions and ensuring fair access to the communication medium.
#
# ### How Token Messages Work:
# 1. Token Circulation: The token is passed from one master station to another in a logical ring, following the ascending numerical order of their addresses. The station with the highest address passes the token back to the station with the lowest address, thus maintaining the logical ring structure.
#
# 2. Token Reception: When a master station receives a token message (DLPDU) addressed to itself from its designated previous station (PS), it gains the right to transmit messages. If the token is received from an unexpected source, the station assumes an error and does not accept the token.
#
# 3. Message Transfer: Once a master station owns the token, it can execute its message transfer periods, allowing it to send data to slave stations or other master stations as needed.
#
# ### Devices Using Token Messages:
# - Master Stations: These are the active devices in a PROFIBUS network that initiate communication and control the token. They can send and receive messages when they possess the token.
# - Slave Stations: While they do not directly use token messages, they respond to requests from master stations that hold the token. They act passively and only transmit data when requested by a master.
#
# ### Benefits of Token Passing:
# - Fair Access: All master stations have equal opportunity to access the communication medium, preventing any single station from monopolizing the bandwidth.
# - Short Reaction Times: The token-passing mechanism allows for predictable and short delays in message delivery, especially for urgent messages.
# - Dynamic Configuration: New master stations can be added or removed from the network without disrupting the existing communication, as the token-passing protocol automatically adjusts to include them.
#
# In summary, token messages are essential for managing communication in PROFIBUS networks, ensuring orderly and efficient data transfer among master stations while maintaining system integrity and performance.

# %% [markdown]
# ### 3 - Which protocol parameter describes the slave's action time after receiving a message?

# %%
question_3 = "Which protocol parameter describes the slave's action time after receiving a message?"
process_question(question_3)
# Out:
# 📚 Retrieved Context:
#
# [{'content': '## **Send Timeout**  \n'
#              "Ce paramètre définit le temps de commande pour surveiller l'AR "
#              'MS2 demandée par le maître DP (Classe 2). Le maître DP et '
#              "l'esclave DP s'informent l'un l'autre du paramètre Send Timeout "
#              "pris en charge. L'esclave DP réajuste son paramètre Send "
#              'Timeout. Le maître DP (Classe 2) déc...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '## **Table 151 – Functions used by DMPMM2**\n'
#              '## **11 Parameters for a DP-slave**  \n'
#              'Table 152 contains limitations for datarate-depending AL timing '
#              'parameters of Slaves.  \n'
#              '| Datarate (kbit/s)         | ≤ 187,5 | 500 | 1 500 | 3 000 | 6 '
#              '000 | 12 000 |\n'
#              '|---------------------------|---------|-----|------...',
#   'id': 'Copia di iec61158-6-3{ed3.0}b'},
#  {'content': 'The DLPDU transmission times (TS/R , TA/R) are determined by the '
#              'number of UART characters (UC). Thus, they are calculated as '
#              'follows:  \n'
#              'TS/R = a × 11 bit, where "a" is the number of UC in a '
#              'send/request DLPDU  \n'
#              'TA/R = b × 11 bit, where "b" is the number of UC in an '
#              'ack/response DLPDU  \n'
#              'EXAMPLE a = ...',
#   'id': 'Copia di iec61158-4-3{ed3.0}b'},
#  {'content': 'For every slave device a fixed time slot according to its data '
#              'width is allocated in the frame. The data package order is '
#              'according to the physical order of the connected devices. Cyclic '
#              'data (process data) and non cyclic data (parameter data) are '
#              'transferred concurrently. Devices with parameter dat...',
#   'id': 'Copia di iec61784-1{ed4.0}b'}]
#
# 🧠 Generated Answer:
#
# The protocol parameter that describes the slave's action time after receiving a message is called Send Timeout.
#
# Send Timeout is a critical parameter in PROFIBUS that defines the maximum time a slave device is allowed to take to respond after it has received a message from the master. This timeout ensures that the master can effectively manage communication and detect any potential issues with the slave's response time.
#
# In the context of PROFIBUS, the Send Timeout value can vary depending on the data rate of the communication. For example, at lower data rates, the Send Timeout can be longer, while at higher data rates, it is typically shorter. This parameter is essential for maintaining the overall efficiency and reliability of the communication within a PROFIBUS network.
#
# By adjusting the Send Timeout, both the master and slave can optimize their communication parameters to ensure timely data exchange and system performance.

# %% [markdown]
# ### 4 - How to calculate DP cycle time?

# %%
question_4 = "How to calculate DP cycle time?"
process_question(question_4)
# Out:
# 📚 Retrieved Context:
#
# [{'content': 'At least the following constraints have to be addressed:  \n'
#              '- at a modular DP-slave the time parameters depend on the '
#              'plugged in modules.\n'
#              '- each module may add also a time offset (each module type may '
#              'have an individual time offset).\n'
#              '- the setting of TI and TO may be restricted.\n'
#              '- the device itself m...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '- Phase 3: conveyance of the value for the Output Data to the '
#              'DP-slave and output of the new Output Data.  \n'
#              'This model of synchronization requires enhanced processing '
#              'capabilities of the DP-master (Class 1) and requires an '
#              'optimized scheduling in the DP-master (Class 1) and in the '
#              'DPslaves.  \n'
#              'The de...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '|       |                              |        '
#              '|                              |                           '
#              '|                   |                           '
#              '|                      | < = T SH => |\n'
#              '|       |                              |        '
#              '|                              | Measured                 ...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '### **6.2.2.4.2.4 Exemple de système DP avec cycle de DP '
#              'isochrone optimisé**  \n'
#              "Dans l'exemple ci-après, les tâches d'application 1 et 2 dans le "
#              'maître DP (Classe 1) peuvent être complètement traitées dans '
#              'chaque cycle de DP isochrone.  \n'
#              '![](_page_535_Figure_1.jpeg)  \n'
#              '![](_page_535_Figure_2.jpeg)  \n'
#              '...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'}]
#
# 🧠 Generated Answer:
#
# To calculate the DP cycle time in a PROFIBUS DP system, you need to consider several key parameters that influence the overall timing. The formula for the dead time (TD) in the context of an isochronous DP cycle is given by:
#
# \[ TD = TDP + TI + TO \]
#
# Where:
# - TDP is the cycle time of the DP system.
# - TI is the time interval for the input data acquisition in the DP-slave, which can vary based on the modules plugged into the slave device.
# - TO is the time offset for the output data, which may also differ depending on the specific module types.
#
# ### Steps to Calculate DP Cycle Time:
#
# 1. Identify TDP: This is the base cycle time for the DP system, which can be determined from the system configuration and the capabilities of the DP-master.
#
# 2. Determine TI: For each DP-slave, assess the time required for input data acquisition. This may involve checking the specifications of each module to find their respective time intervals.
#
# 3. Determine TO: Similarly, evaluate the time offset for output data for each module. Each module may have a different TO based on its design and function.
#
# 4. Consider Additional Offsets: If the device itself adds any additional time due to the transfer of I/O data between the interface device and the modules, this should also be included in the calculation.
#
# 5. Sum the Values: Once you have all the necessary values, plug them into the formula to calculate the total dead time (TD), which represents the cycle time for the DP system.
#
# ### Example:
# If you have:
# - TDP = 10 ms
# - TI = 2 ms (for the input module)
# - TO = 3 ms (for the output module)
#
# Then the total dead time (TD) would be:
# \[ TD = 10 \, \text{ms} + 2 \, \text{ms} + 3 \, \text{ms} = 15 \, \text{ms} \]
#
# This means the DP cycle time for this configuration would be 15 ms.
#
# ### Optimization Considerations:
# - Ensure that the acquisition of input data (TI) occurs as close to the end of the isochronous DP cycle as possible to provide the most current data.
# - Similarly, the output of data (TO) should be executed at the end of the cyclic part of the DP cycle to minimize delays in output data availability.
# - The processing time (TM) in the DP-master should also be optimized to ensure that all tasks are completed within the current cycle to maintain synchronization.
#
# By following these steps and considerations, you can effectively calculate and optimize the DP cycle time in a PROFIBUS DP system.

# %% [markdown]
# ### 5 - Briefly explain the function of a watchdog timer in a PROFIBUS DP slave.

# %%
question_5 = "Briefly explain the function of a watchdog timer in a PROFIBUS DP slave."
process_question(question_5)
# Out:
# 📚 Retrieved Context:
#
# [{'content': '## <span id="page-94-0"></span>**6.9 Application relationship '
#              'monitoring**\n'
#              '## **6.9.1 Monitoring of the MS0 – AR**\n'
#              '## **6.9.1.1 General**  \n'
#              'In industrial control systems there is a need for checking the '
#              'correct functioning of each individual part. In such a system a '
#              'medium failure or a defect in a b...',
#   'id': 'Copia di iec61158-6-3{ed3.0}b'},
#  {'content': '| host-timer     |                 | Timer             | This '
#              'timer checks whether the next valid safety PDU from the F-Device '
#              'did<br>arrive in time. The host engineering tool is responsible '
#              'to define this watchdog<br>time. Value range is 0 … 65535 '
#              'ms.                                                ...',
#   'id': 'Copia di PROFIsafe-Profile_3192b_V24_Mar07'},
#  {'content': '![](_page_95_Figure_10.jpeg)  \n'
#              '**Figure 73 — Timing sections forming the FSCP 3/1 '
#              'F\\_WD\\_Time**  \n'
#              'The transfer of the new safety PDU to the F-Host characterises '
#              'the next timing section (Bus). As soon as the F driver in the '
#              'F-Host received the new safety PDU it restarts its watchdog '
#              'timer and process...',
#   'id': 'Copia di PROFIsafe-Profile_3192b_V24_Mar07'},
#  {'content': '**idle-timer:** This timer monitors the idle state (binary "1"), '
#              'the synchronization time, immediately on the bus line. The '
#              'synchronization time preceding each request is necessary for '
#              'unambiguous receiver synchronization. The idle-timer of Slave '
#              'stations and Master stations "without token" is loade...',
#   'id': 'Copia di iec61158-4-3{ed3.0}b'}]
#
# 🧠 Generated Answer:
#
# A watchdog timer in a PROFIBUS DP slave serves to ensure the safe operation of the device by monitoring communication with the bus master. If the watchdog timer expires without receiving a valid request from the bus master, the slave will automatically switch its outputs to a safe state. This mechanism is crucial for maintaining system safety, especially in the event of communication failures or malfunctions.
#
# The watchdog timer is reset each time a valid request is received from the bus master. If the timer reaches its set limit without being reset, it indicates that the slave has not received timely communication, prompting it to take protective action. This helps prevent potential hazards that could arise from a malfunctioning device or communication breakdown, ensuring that the slave device does not remain in an undefined or unsafe state.
#
# For example, if a PROFIBUS DP slave is controlling a motor, and the watchdog timer expires due to a loss of communication with the master, the slave will deactivate the motor to prevent any unsafe operation. The configuration of the watchdog timer, including its duration, is typically defined by the host engineering tool and must be carefully set to balance safety and system availability.

# %% [markdown]
# ### 6 - Briefly explain the meaning of “sync” and “freeze” modes. Which device(s) must support these modes?

# %%
question_6 = "Briefly explain the meaning of “sync” and “freeze” modes. Which device(s) must support these modes?"
process_question(question_6)
# Out:
# 📚 Retrieved Context:
#
# [{'content': 'The values of the I/O Data objects of all or a group of '
#              'DP-slaves within a given network may be synchronized by its '
#              'assigned DP-master with help of the Global Control service.  \n'
#              'The synchronization of the values of the Input Data objects is '
#              'achieved by the Freeze Command and the synchronization of t...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '### **Sync Mode**  \n'
#              'This dynamic attribute indicates if the Sync mode is activated. '
#              'This attribute shall always be set to FALSE if the attribute '
#              'Sync Supported has the value FALSE. If the attribute Sync '
#              'Supported has the value TRUE the following rules shall apply for '
#              'the attribute Sync Mode:  \n'
#              '- It ...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '### <span id="page-223-0"></span>**7.2.3.2.5.4 Synch / '
#              'freeze**  \n'
#              'Synch / freeze functionality is described in IEC 61158-5-3, '
#              '6.2.2, I/O Data ASE.  \n'
#              'This option may be used for DP-V1 / DP-V0 – DP-master (Class 1), '
#              '(see [7.2.3.1.2.2](#page-170-2) / [7.2.3.1.2.1\\)](#page-165-2), '
#              'and DP-V1 / DP-V0 – DP...',
#   'id': 'Copia di iec61784-1{ed4.0}b'},
#  {'content': '### **Table 209 – Isochronous mode**  \n'
#              '| Value                 | '
#              'Meaning                                                                                '
#              '|\n'
#              '|-----------------------|----------------------------------------------------------------------------------------|\n'
#              '| Not Synchronized      | the D...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'}]
#
# 🧠 Generated Answer:
#
# In PROFIBUS, "sync" and "freeze" modes are mechanisms used to synchronize the data between a DP-master and its associated DP-slaves.
#
# ### Sync Mode
# The Sync mode is activated when a Sync command is received from the DP-master. This command instructs the DP-slaves to update their Output Data objects to the master’s buffer. The Sync mode can be deactivated with an Unsync command. When Sync mode is active, the DP-slaves will transmit the current values of their Output Data objects, ensuring that the data is consistent across the network.
#
# ### Freeze Mode
# The Freeze mode is used to temporarily hold the current values of the Input Data objects in the DP-slaves. When a Freeze command is issued, the values in the Input Data objects are "frozen," meaning that any updates to these values by the server application will not be reflected until the next Freeze command is received. The Freeze mode can be deactivated with an Unfreeze command.
#
# ### Device Support
# Both the DP-master (Class 1) and the DP-slaves must support these modes for synchronization to function correctly. The DP-master initiates the commands, while the DP-slaves must be capable of responding to these commands to participate in the synchronization process. The ability to support Freeze and Sync modes is indicated by specific attributes (e.g., Freeze Supported and Sync Supported) in the DP-slaves, which are set during the parameterization phase.

# %% [markdown]
# ### 7 - Discuss the factors that have a significant effect on the overall cycle time of a DP network.

# %%
question_7 = "Discuss the factors that have a significant effect on the overall cycle time of a DP network."
process_question(question_7)
# Out:
# 📚 Retrieved Context:
#
# [{'content': 'At least the following constraints have to be addressed:  \n'
#              '- at a modular DP-slave the time parameters depend on the '
#              'plugged in modules.\n'
#              '- each module may add also a time offset (each module type may '
#              'have an individual time offset).\n'
#              '- the setting of TI and TO may be restricted.\n'
#              '- the device itself m...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '### **6.2.2.4.2.4 Exemple de système DP avec cycle de DP '
#              'isochrone optimisé**  \n'
#              "Dans l'exemple ci-après, les tâches d'application 1 et 2 dans le "
#              'maître DP (Classe 1) peuvent être complètement traitées dans '
#              'chaque cycle de DP isochrone.  \n'
#              '![](_page_535_Figure_1.jpeg)  \n'
#              '![](_page_535_Figure_2.jpeg)  \n'
#              '...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '- Phase 3: conveyance of the value for the Output Data to the '
#              'DP-slave and output of the new Output Data.  \n'
#              'This model of synchronization requires enhanced processing '
#              'capabilities of the DP-master (Class 1) and requires an '
#              'optimized scheduling in the DP-master (Class 1) and in the '
#              'DPslaves.  \n'
#              'The de...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '#### **Figure 73 – Simplified typical response time model**  \n'
#              'The example represents a signal path consisting of a sensor '
#              "device, the bus transfer to the F-Host, the F-Host's processing, "
#              'another bus transfer to the output device, and the output device '
#              '(final element).  \n'
#              '<span id="page-102-0"></span>...',
#   'id': 'Copia di iec61784-3-3{ed2.0}en'}]
#
# 🧠 Generated Answer:
#
# The overall cycle time of a PROFIBUS DP network is influenced by several key factors:
#
# 1. Modular DP-Slave Configuration: The time parameters for a modular DP-slave depend on the specific modules that are plugged in. Each module can have different processing times and functionalities, which can significantly affect the overall cycle time. For instance, a module designed for high-speed data acquisition may have a shorter processing time compared to a module that handles complex calculations.
#
# 2. Time Offsets for Each Module: Each module type may introduce an individual time offset. This means that the total cycle time will include the cumulative offsets from all active modules. If a module has a longer time offset due to its internal processing requirements, it will delay the overall cycle time.
#
# 3. Setting of TI (Input Time) and TO (Output Time): The configuration of TI and TO can be restricted based on the capabilities of the DP-slave and the requirements of the application. If these times are set too high, they can lead to increased cycle times, as the system will wait longer to acquire input data or to send output data.
#
# 4. Device Transfer Time: The device itself may add an additional time offset due to the transfer time of I/O data between the interface device and the modules. This transfer time can vary based on the bus load, the number of devices on the network, and the specific communication protocols in use.
#
# 5. Processing Time in the DP-Master: The DP-master (Class 1) processes application tasks based on the input data received from the DP-slaves. The time taken to process these tasks can vary, and if the processing is not optimized, it can lead to delays in the cycle time. The processing must be completed within the current cycle to ensure timely output data is sent to the DP-slaves.
#
# 6. Synchronization and Dead Time: The synchronization of the DP network is crucial. The dead time in the synchronization model is given by the formula: TD = TDP + TI + TO. This means that any delays in data acquisition (TDP), input time (TI), and output time (TO) will contribute to the overall cycle time.
#
# In summary, optimizing the configuration of DP-slaves, minimizing time offsets, carefully setting TI and TO, and ensuring efficient processing in the DP-master are all critical to reducing the overall cycle time in a PROFIBUS DP network.

# %% [markdown]
# ### 8 - What are the four operating modes of a DP class 1 master? Briefly explain the interaction between the master and its assigned slaves in each mode.

# %%
question_8 = "What are the four operating modes of a DP class 1 master? Briefly explain the interaction between the master and its assigned slaves in each mode."
process_question(question_8)
# Out:
# 📚 Retrieved Context:
#
# [{'content': '### **Figure 3 – Example of DP communication between field '
#              'devices**\n'
#              '### **6.1.3.2 Device types**\n'
#              '### **6.1.3.2.1 DP-master (class 1)**  \n'
#              'The DP-master (Class 1) is a controlling device which is '
#              'associated with one or more DPslaves (field devices). The '
#              'DP-master (Class 1) performs one or more of the...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': 'If there exists a valid Master Parameter Set in a DP-master '
#              '(Class 1), this device starts to check whether the DP-slaves '
#              'dedicated to that DP-master are present or not (this will be '
#              'done with a read of the diagnosis of a DP-slave). After an '
#              'appropriate answer the DP-master (Class 1) will set the par...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '## **6.1.3.2.2 DP-master (class 2)**  \n'
#              'The DP-master (Class 2) is a controlling device which manages '
#              'provision of configuration data (parameter sets) and collection '
#              'of Diagnosis data for/from a DP-master (Class 1). Additionally '
#              'the DP-master (Class 2) can perform all basic and some extended '
#              'communic...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': 'The DP-master (Class 1) is a controlling device, which is '
#              'associated with one or more DP-Slaves (field devices). The '
#              'DP-master (Class 1) performs basic functionalities and '
#              'optionally DPV1 features.  \n'
#              'The DP-master (Class 2) is a controlling device, which manages '
#              'configuration data (parameter sets) a...',
#   'id': 'Copia di iec61784-1{ed4.0}b'}]
#
# 🧠 Generated Answer:
#
# The four operating modes of a DP Class 1 master in PROFIBUS are:
#
# 1. Clear Mode: In this mode, the DP Class 1 master is not actively communicating with the DP slaves. It is essentially in a standby state, where it can perform diagnostics and configuration checks but does not exchange I/O data. The master informs the slaves that it is in Clear Mode, and they will not respond to data exchange requests.
#
# 2. Operate Mode: When the DP Class 1 master enters Operate Mode, it actively exchanges I/O data with the assigned DP slaves. The master sends requests for data, and the slaves respond with their current status and data. This mode is essential for the normal operation of the system, as it allows for real-time data communication.
#
# 3. Configuration Mode: In this mode, the DP Class 1 master configures the DP slaves. It sends configuration parameters to the slaves, which must accept these parameters before entering the Operate Mode. The master checks the configuration of each slave and ensures that they are correctly set up for communication.
#
# 4. Diagnosis Mode: The Diagnosis Mode allows the DP Class 1 master to read diagnostic information from the DP slaves. This is crucial for monitoring the health and status of the slaves. If any issues arise, the slaves can send high-priority diagnostic messages to the master, which can then inform the local user about any faults or alarms.
#
# In summary, the interaction between the DP Class 1 master and its assigned slaves varies depending on the mode. In Clear Mode, there is no data exchange; in Operate Mode, data is actively exchanged; in Configuration Mode, the master sets up the slaves; and in Diagnosis Mode, the master retrieves diagnostic information from the slaves.

# %% [markdown]
# ### 9 - The data unit of a configuration telegram contains the following 3 bytes represented in hexadecimal notation. Decode the meaning of the bytes. \n- Byte 0:  D1 \n- Byte 1:  23 \n- Byte 2:  70

# %%
question_9 = "The data unit of a configuration telegram contains the following 3 bytes represented in hexadecimal notation. Decode the meaning of the bytes. \n- Byte 0:  D1 \n- Byte 1:  23 \n- Byte 2:  70"
process_question(question_9)
# Out:
# 📚 Retrieved Context:
#
# [{'content': '|--------|------------------|---|---|---|---|---|---|---|-------------------------------------------------------|\n'
#              '| octets |                  |   |   |   |   |   |   |   '
#              '|                                                       |\n'
#              '| 1      | 0                | 0 | 0 | 0 | 0 | 1 | 0 | 0 | device '
#              'related...',
#   'id': 'Copia di iec61158-6-3{ed3.0}b'},
#  {'content': '- 00 basic configuration message;\n'
#              '- 01 path-diversity control message;\n'
#              '- 10 extendible configuration message;\n'
#              '- 11 extendible status-report invocation message.\n'
#              '### **8.2.2.4.2 Basic configuration message**  \n'
#              'Following its initial two bits of (00), the basic configuration '
#              'message specifies operationa...',
#   'id': 'Copia di iec61158-2{ed6.0}b'},
#  {'content': '| 0                               | '
#              '2                               | 8                          | '
#              'Idle            | '
#              '0x48                                             |  |\n'
#              '| 0                               | '
#              '2                               | 9 to 16                    | '
#              'reserved        | 0x49 to 0x50...',
#   'id': 'Copia di iec61158-6-3{ed3.0}b'},
#  {'content': '## **7.1.3 Status and Control Byte**  \n'
#              '| Bit7 | Bit6                           | Bit5       | '
#              'Bit4                               | '
#              'Bit3                                   | '
#              'Bit2                            | '
#              'Bit1                                         | '
#              'Bit0                                           ...',
#   'id': 'Copia di iec61784-3-3{ed2.0}en'}]
#
# 🧠 Generated Answer:
#
# To decode the meaning of the bytes in the configuration telegram, we analyze each byte in hexadecimal notation:
#
# - Byte 0: D1 (hex)
#   In binary, D1 is represented as `11010001`. The first two bits (`11`) indicate that this is an extendible status-report invocation message. The remaining bits provide additional information, which may include operational modes or specific device diagnostics.
#
# - Byte 1: 23 (hex)
#   In binary, 23 is represented as `00100011`. This byte typically contains device-specific information or diagnostic data. The bits can indicate various statuses or configurations related to the device.
#
# - Byte 2: 70 (hex)
#   In binary, 70 is represented as `01110000`. This byte may also contain diagnostic information, possibly related to the operational state of the device or specific identifiers for diagnostics.
#
# ### Summary of the Bytes:
# - Byte 0 (D1): Indicates the type of message (extendible status-report invocation).
# - Byte 1 (23): Contains device-specific diagnostic information.
# - Byte 2 (70): Provides additional diagnostic data, potentially related to the operational state.
#
# In the context of PROFIBUS, these bytes are part of a configuration telegram that communicates the status and configuration of devices within the network, allowing for effective monitoring and control in industrial automation systems.

# %% [markdown]
# ### 10 - Briefly explain how a slave device, which is in cyclic data exchange, communicates the presence of a diagnostic fault to its controlling master. What does the master do about this?

# %%
question_10 = "Briefly explain how a slave device, which is in cyclic data exchange, communicates the presence of a diagnostic fault to its controlling master. What does the master do about this?"
process_question(question_10)
# Out:
# 📚 Retrieved Context:
#
# [{'content': 'For every slave device a fixed time slot according to its data '
#              'width is allocated in the frame. The data package order is '
#              'according to the physical order of the connected devices. Cyclic '
#              'data (process data) and non cyclic data (parameter data) are '
#              'transferred concurrently. Devices with parameter dat...',
#   'id': 'Copia di iec61784-1{ed4.0}b'},
#  {'content': 'Only in the data exchange mode the extended functionalities like '
#              'the acyclic read and write of variables, the acyclic transfer of '
#              'alarms, the up- and/or download of LR Data, the invocation of '
#              'stateless and/or state-oriented functions, the DXB functionality '
#              'and the Isochronous Mode are possible if su...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': 'If there exists a valid Master Parameter Set in a DP-master '
#              '(Class 1), this device starts to check whether the DP-slaves '
#              'dedicated to that DP-master are present or not (this will be '
#              'done with a read of the diagnosis of a DP-slave). After an '
#              'appropriate answer the DP-master (Class 1) will set the par...',
#   'id': 'Copia di iec61158-5-3{ed3.0}b'},
#  {'content': '## **6.6 Cyclic communication between DP-master (class 1) and '
#              'DP-slave**  \n'
#              'The communication between DP-master and DP-slave is established '
#              'with the sequence as shown in Figure 16:  \n'
#              'If the DP-master wants to communicate with a DP-slave, the '
#              'DP-master requests the Diag\\_Data of the DP-slave, in order...',
#   'id': 'Copia di iec61158-6-3{ed3.0}b'}]
#
# 🧠 Generated Answer:
#
# In PROFIBUS, when a slave device in cyclic data exchange detects a diagnostic fault, it communicates this to its controlling master by sending a specific diagnostic response during the data exchange cycle. This response includes information about the fault, which can be in the form of error codes or status messages indicating the nature of the issue.
#
# Upon receiving this diagnostic information, the master (Class 1) evaluates the response. If the diagnostic data indicates a fault, the master will typically take one of the following actions:
#
# 1. Recheck Readiness: The master may initiate a new request for diagnostic data to confirm the fault and check if the slave is still operational or if the fault has been resolved.
#
# 2. Error Handling: Depending on the type of fault reported, the master may decide to halt data exchange with the affected slave, reconfigure it, or take corrective actions as necessary.
#
# 3. Notification: The master can inform its local user or system about the fault, allowing for appropriate maintenance or troubleshooting actions to be taken.
#
# 4. Retry Mechanism: If the fault is transient, the master may implement a retry mechanism to attempt communication with the slave again after a certain period.
#
# In summary, the master actively monitors the diagnostic information from the slave and responds accordingly to ensure the integrity and reliability of the communication and the overall system operation.
